# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin','Embarked'], axis=1)

# %%
sns.countplot(x='Pclass', data=df,hue="Sex")
plot.xlabel('Passenger Class')
plot.title("Passenger Class Count")
# Out:
# Text(0.5, 1.0, 'Passenger Class Count')

# %%
sns.histplot(data=df, x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.countplot(x='Sex',data=df,hue='Survived')
plot.show()

# %%
plot.figure(figsize=(12, 8))
sns.countplot(x='Pclass', hue='Survived', data=df, palette='Set2')
plot.title('Survival Count by Class')
plot.xlabel('Passenger Class')
plot.ylabel('Count')
plot.show()

# %%
sns.histplot(df['Age'].dropna(), bins=30,kde=True)
plot.title('Distribution of Age')
plot.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.histplot(df['Fare'], bins=30, kde=True, color='skyblue')
plot.title('Distribution of Ticket Prices')
plot.xlabel('Fare')
plot.ylabel('Frequency')
plot.show()

# %%
sns.set(style="whitegrid")

plot.figure(figsize=(10, 6))
sns.boxplot(x='Sex', y='Age', hue='Survived', data=df)
plot.title('Boxplot of Age by Gender and Survival')
plot.show()

# %%
sns.boxplot(x='Pclass', y='Age', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x='Sex', y='Age', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df['Sex'] = df['Sex'].replace(['male', 'female'], [0, 1])
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    0  22.0      1      0   7.2500
# 1           1       1    1  38.0      1      0  71.2833
# 2           1       3    1  26.0      0      0   7.9250
# 3           1       1    1  35.0      1      0  53.1000
# 4           0       3    0  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    0  27.0      0      0  13.0000
# 887         1       1    1  19.0      0      0  30.0000
# 888         0       3    1   NaN      1      2  23.4500
# 889         1       1    0  26.0      0      0  30.0000
# 890         0       3    0  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >
